# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("dataset_Facebook.csv",sep=";")

# %%
plt.subplot(2,2,1)
plt.bar(df['Type'],df['Total Interactions'])
plt.xlabel('Type')
plt.ylabel('Total Interactions')
plt.title('Total Interaction by Type')
# Out:
# Text(0.5, 1.0, 'Total Interaction by Type')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0     0.0                       2752                             5091
# 1     0.0                      10460                            19057
# 2     0.0                       2413                             4373
# 3     1.0                      50128                            87991
# 4     0.0                       7244                            13594
# ..    ...                        ...                              ...
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                       178                      109
# 1                      1457                     1361
# 2                       177                      113
# 3                      2211                      790
# 4                       671                      410
# ..                      ...                      ...
# 495                     733                      708
# 496                     537                      508
# 497                     625                      572
# 498                     626                      574
# 499                     564                      524
#
#      Lifetime Post Consumptions  \
# 0                           159
# 1                          1674
# 2                           154
# 3                          1119
# 4                           580
# ..                          ...
# 495                         985
# 496                         687
# 497                         795
# 498                         832
# 499                         743
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 0                                                 3078
# 1                                                11710
# 2                                                 2812
# 3                                                61027
# 4                                                 6228
# ..                                                 ...
# 495                                               4750
# 496                                               3961
# 497                                               4742
# 498                                               4534
# 499                                               3861
#
#      Lifetime Post reach by people who like your Page  \
# 0                                                1640
# 1                                                6112
# 2                                                1503
# 3                                               32048
# 4                                                3200
# ..                                                ...
# 495                                              2876
# 496                                              2104
# 497                                              2388
# 498                                              2452
# 499                                              2200
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 0                                                  119
# 1                                                 1108
# 2                                                  132
# 3                                                 1386
# 4                                                  396
# ..                                                 ...
# 495                                                392
# 496                                                301
# 497                                                363
# 498                                                370
# 499                                                316
#
#      comment    like  share  Total Interactions
# 0          4    79.0   17.0                 100
# 1          5   130.0   29.0                 164
# 2          0    66.0   14.0                  80
# 3         58  1572.0  147.0                1777
# 4         19   325.0   49.0                 393
# ..       ...     ...    ...                 ...
# 495        5    53.0   26.0                  84
# 496        0    53.0   22.0                  75
# 497        4    93.0   18.0                 115
# 498        7    91.0   38.0                 136
# 499        0    91.0   28.0                 119
#
# [500 rows x 19 columns]

# %%
plt.scatter(df['Lifetime Post Total Reach'],df['Lifetime Post Total Impressions'])
plt.xlabel('Lifetime Post Total Reach')
plt.ylabel('Lifetime Post Total Impressions')
plt.title('Lifetime Post Total Reach vs. Impressions')
# Out:
# Text(0.5, 1.0, 'Lifetime Post Total Reach vs. Impressions')

# %%
plt.hist(df['Lifetime Engaged Users'])
plt.xlabel('Lifetime Engaged User')
plt.ylabel('Frequency')
plt.title('Lifetime Engaged Users Distribution')
# Out:
# Text(0.5, 1.0, 'Lifetime Engaged Users Distribution')

# %%
plt.boxplot([df[df['Category'] == 1]['Lifetime Post Consumers'],
             df[df['Category']==2]['Lifetime Post Consumers'],
            df[df['Category']==3]['Lifetime Post Consumers']],
            labels=['Category 1', 'Category 2', 'Category 3'])
plt.xlabel('Category')
plt.ylabel('Lifetime Post Consumers')
plt.title('Lifetime Post Consumers by Category')

plt.tight_layout()  # Adjust the spacing between subplots
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
air_quality_data = pd.read_csv('air_quality_data.csv')
plt.figure(figsize=(10, 6))
sns.lineplot(data=air_quality_dat.drop('Date', axis=1))
plt.title('Air Quality Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Concentration')
plt.xticks(rotation=45)
plt.legend(title='Pollutants')
plt.show()
